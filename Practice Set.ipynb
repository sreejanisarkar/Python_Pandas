# %%
import pandas as pd
import numpy as np

# %%
newdf = pd.read_csv(r"C:\Users\Hp\Downloads\Untitled spreadsheet - city_level_cases_and_deaths.csv")
newdf
# Out:
#           date state        location city_or_county  cases_total  cases_white  \
# 0     7/1/2020    CA  Alameda County         County         6384          653
# 1     7/2/2020    CA  Alameda County         County         6472          667
# 2     7/4/2020    CA  Alameda County         County         6855          708
# 3     7/5/2020    CA  Alameda County         County         6887          711
# 4    7/10/2020    CA  Alameda County         County         7725          816
# ..         ...   ...             ...            ...          ...          ...
# 495  7/19/2020    FL    Duval County         County        16546         4008
# 496  7/20/2020    FL    Duval County         County        17245         4171
# 497  7/21/2020    FL    Duval County         County        17544         4253
# 498  7/22/2020    FL    Duval County         County        17979         4326
# 499  7/23/2020    FL    Duval County         County        18357         4402
#
# ...

# %%
newdf.head(10)
# Out:
#         date state                                           location  \
# 0   7/1/2020    CA                                     Alameda County
# 1   7/2/2020    CA                                     Alameda County
# 2   7/4/2020    CA                                     Alameda County
# 3   7/5/2020    CA                                     Alameda County
# 4  7/10/2020    CA                                     Alameda County
# 5  7/17/2020    CA                                     Alameda County
# 6   6/3/2020    CA  Los Angeles County (without the cities of Long...
# 7   6/4/2020    CA  Los Angeles County (without the cities of Long...
# 8   6/5/2020    CA  Los Angeles County (without the cities of Long...
# 9   6/6/2020    CA  Los Angeles County (without the cities of Long...
#
#   city_or_county  cases_total  cases_white  cases_black  cases_latinx  \
# 0         County         6384          653          483        3379.0
# ...

# %%
newdf.tail(10)
# Out:
#           date state      location city_or_county  cases_total  cases_white  \
# 490  7/14/2020    FL  Duval County         County        13724         3414
# 491  7/15/2020    FL  Duval County         County        14152         3557
# 492  7/16/2020    FL  Duval County         County        14992         3729
# 493  7/17/2020    FL  Duval County         County        15641         3856
# 494  7/18/2020    FL  Duval County         County        15903         3930
# 495  7/19/2020    FL  Duval County         County        16546         4008
# 496  7/20/2020    FL  Duval County         County        17245         4171
# 497  7/21/2020    FL  Duval County         County        17544         4253
# 498  7/22/2020    FL  Duval County         County        17979         4326
# 499  7/23/2020    FL  Duval County         County        18357         4402
#
#      cases_black  cases_latinx  cases_asian  cases_aian  ...  \
# 490         4098           NaN          NaN         NaN  ...
# ...

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 39 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   date                          500 non-null    object
#  1   state                         500 non-null    object
#  2   location                      500 non-null    object
#  3   city_or_county                500 non-null    object
#  4   cases_total                   500 non-null    int64
#  5   cases_white                   500 non-null    int64
#  6   cases_black                   500 non-null    int64
#  7   cases_latinx                  345 non-null    float64
#  8   cases_asian                   345 non-null    float64
#  9   cases_aian                    297 non-null    float64
#  10  cases_hnpi                    345 non-null    float64
#  11  cases_multiracial             191 non-null    float64
# ...

# %%
newdf.describe()
# Out:
#          cases_total  cases_white  cases_black   cases_latinx  cases_asian  \
# count     500.000000    500.00000   500.000000     345.000000   345.000000
# mean    41024.386000   4505.34000  1619.110000   20673.582609  2086.371014
# std     69625.464769   4998.00867  1991.657725   27692.591000  2443.781986
# min       880.000000    396.00000    55.000000    1161.000000   181.000000
# 25%      4640.250000   1342.75000   397.250000    3680.000000   362.000000
# 50%      7994.500000   2798.50000   775.000000    6147.000000   723.000000
# 75%     25144.000000   4691.75000  1866.000000   27671.000000  3644.000000
# max    275040.000000  22840.00000  8364.000000  105192.000000  8691.000000
#
#        cases_aian  cases_hnpi  cases_multiracial   cases_other  cases_unknown  \
# count  297.000000  345.000000         191.000000    353.000000     476.000000
# mean    80.417508  203.275362         189.376963   6792.943343   14823.716387
# ...

# %%
newdf.head(20)
# Out:
#          date state                                           location  \
# 0    7/1/2020    CA                                     Alameda County
# 1    7/2/2020    CA                                     Alameda County
# 2    7/4/2020    CA                                     Alameda County
# 3    7/5/2020    CA                                     Alameda County
# 4   7/10/2020    CA                                     Alameda County
# 5   7/17/2020    CA                                     Alameda County
# 6    6/3/2020    CA  Los Angeles County (without the cities of Long...
# 7    6/4/2020    CA  Los Angeles County (without the cities of Long...
# 8    6/5/2020    CA  Los Angeles County (without the cities of Long...
# 9    6/6/2020    CA  Los Angeles County (without the cities of Long...
# 10   6/7/2020    CA  Los Angeles County (without the cities of Long...
# 11   6/8/2020    CA  Los Angeles County (without the cities of Long...
# ...

# %%
df = newdf.dropna()
df
# Out:
#           date state           location city_or_county  cases_total  \
# 113   7/7/2020    CA  Orange County, CA         County        18892
# 114   7/8/2020    CA  Orange County, CA         County        20225
# 115   7/9/2020    CA  Orange County, CA         County        21517
# 116  7/10/2020    CA  Orange County, CA         County        22650
# 118  7/14/2020    CA  Orange County, CA         County        26120
# 119  7/15/2020    CA  Orange County, CA         County        27031
# 120  7/16/2020    CA  Orange County, CA         County        27904
# 121  7/17/2020    CA  Orange County, CA         County        28309
# 124  7/21/2020    CA  Orange County, CA         County        30976
# 125  7/22/2020    CA  Orange County, CA         County        31743
# 126  7/23/2020    CA  Orange County, CA         County        32648
# 127  7/24/2020    CA  Orange County, CA         County        33358
# 128  7/25/2020    CA  Orange County, CA         County        33953
# ...

# %%
newdf.head()
# Out:
#         date state        location city_or_county  cases_total  cases_white  \
# 0   7/1/2020    CA  Alameda County         County         6384          653
# 1   7/2/2020    CA  Alameda County         County         6472          667
# 2   7/4/2020    CA  Alameda County         County         6855          708
# 3   7/5/2020    CA  Alameda County         County         6887          711
# 4  7/10/2020    CA  Alameda County         County         7725          816
#
#    cases_black  cases_latinx  cases_asian  cases_aian  ...  \
# 0          483        3379.0        771.0        18.0  ...
# 1          488        3422.0        779.0        18.0  ...
# 2          516        3546.0        803.0        18.0  ...
# 3          517        3555.0        805.0        19.0  ...
# 4          571        3908.0        863.0        22.0  ...
#
#    deaths_ethnicity_unknown  case_fatality_rate  daily_new_cases  \
# 0                       2.0                2.16            135.0
# ...

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
x = newdf["cases_white"].mode()[0]
x
# Out:
# 456

# %%
print("Hello world!")
# Out:
# Hello world!
